# %%
# imports
import os
import sys
import types
import json
import base64

# figure size/format
fig_width = 7
fig_height = 5
fig_format = 'retina'
fig_dpi = 96
interactivity = ''
is_shiny = False
is_dashboard = False
plotly_connected = True

# matplotlib defaults / format
try:
  import matplotlib.pyplot as plt
  plt.rcParams['figure.figsize'] = (fig_width, fig_height)
  plt.rcParams['figure.dpi'] = fig_dpi
  plt.rcParams['savefig.dpi'] = "figure"
  from IPython.display import set_matplotlib_formats
  set_matplotlib_formats(fig_format)
except Exception:
  pass

# plotly use connected mode
try:
  import plotly.io as pio
  if plotly_connected:
    pio.renderers.default = "notebook_connected"
  else:
    pio.renderers.default = "notebook"
  for template in pio.templates.keys():
    pio.templates[template].layout.margin = dict(t=30,r=0,b=0,l=0)
except Exception:
  pass

# disable itables paging for dashboards
if is_dashboard:
  try:
    from itables import options
    options.dom = 'fiBrtlp'
    options.maxBytes = 1024 * 1024
    options.language = dict(info = "Showing _TOTAL_ entries")
    options.classes = "display nowrap compact"
    options.paging = False
    options.searching = True
    options.ordering = True
    options.info = True
    options.lengthChange = False
    options.autoWidth = False
    options.responsive = True
    options.keys = True
    options.buttons = []
  except Exception:
    pass
  
  try:
    import altair as alt
    # By default, dashboards will have container sized
    # vega visualizations which allows them to flow reasonably
    theme_sentinel = '_quarto-dashboard-internal'
    def make_theme(name):
        nonTheme = alt.themes._plugins[name]    
        def patch_theme(*args, **kwargs):
            existingTheme = nonTheme()
            if 'height' not in existingTheme:
              existingTheme['height'] = 'container'
            if 'width' not in existingTheme:
              existingTheme['width'] = 'container'

            if 'config' not in existingTheme:
              existingTheme['config'] = dict()
            
            # Configure the default font sizes
            title_font_size = 15
            header_font_size = 13
            axis_font_size = 12
            legend_font_size = 12
            mark_font_size = 12
            tooltip = False

            config = existingTheme['config']

            # The Axis
            if 'axis' not in config:
              config['axis'] = dict()
            axis = config['axis']
            if 'labelFontSize' not in axis:
              axis['labelFontSize'] = axis_font_size
            if 'titleFontSize' not in axis:
              axis['titleFontSize'] = axis_font_size  

            # The legend
            if 'legend' not in config:
              config['legend'] = dict()
            legend = config['legend']
            if 'labelFontSize' not in legend:
              legend['labelFontSize'] = legend_font_size
            if 'titleFontSize' not in legend:
              legend['titleFontSize'] = legend_font_size  

            # The header
            if 'header' not in config:
              config['header'] = dict()
            header = config['header']
            if 'labelFontSize' not in header:
              header['labelFontSize'] = header_font_size
            if 'titleFontSize' not in header:
              header['titleFontSize'] = header_font_size    

            # Title
            if 'title' not in config:
              config['title'] = dict()
            title = config['title']
            if 'fontSize' not in title:
              title['fontSize'] = title_font_size

            # Marks
            if 'mark' not in config:
              config['mark'] = dict()
            mark = config['mark']
            if 'fontSize' not in mark:
              mark['fontSize'] = mark_font_size

            # Mark tooltips
            if tooltip and 'tooltip' not in mark:
              mark['tooltip'] = dict(content="encoding")

            return existingTheme
            
        return patch_theme

    # We can only do this once per session
    if theme_sentinel not in alt.themes.names():
      for name in alt.themes.names():
        alt.themes.register(name, make_theme(name))
      
      # register a sentinel theme so we only do this once
      alt.themes.register(theme_sentinel, make_theme('default'))
      alt.themes.enable('default')

  except Exception:
    pass

# enable pandas latex repr when targeting pdfs
try:
  import pandas as pd
  if fig_format == 'pdf':
    pd.set_option('display.latex.repr', True)
except Exception:
  pass

# interactivity
if interactivity:
  from IPython.core.interactiveshell import InteractiveShell
  InteractiveShell.ast_node_interactivity = interactivity

# NOTE: the kernel_deps code is repeated in the cleanup.py file
# (we can't easily share this code b/c of the way it is run).
# If you edit this code also edit the same code in cleanup.py!

# output kernel dependencies
kernel_deps = dict()
for module in list(sys.modules.values()):
  # Some modules play games with sys.modules (e.g. email/__init__.py
  # in the standard library), and occasionally this can cause strange
  # failures in getattr.  Just ignore anything that's not an ordinary
  # module.
  if not isinstance(module, types.ModuleType):
    continue
  path = getattr(module, "__file__", None)
  if not path:
    continue
  if path.endswith(".pyc") or path.endswith(".pyo"):
    path = path[:-1]
  if not os.path.exists(path):
    continue
  kernel_deps[path] = os.stat(path).st_mtime
print(json.dumps(kernel_deps))

# set run_path if requested
run_path = 'QzpcVXNlcnNcRWR3aW4gUmV5ZXNcRG9jdW1lbnRzXGN1cnNvX29wZW5haV9hcGk='
if run_path:
  # hex-decode the path
  run_path = base64.b64decode(run_path.encode("utf-8")).decode("utf-8")
  os.chdir(run_path)

# reset state
# %reset

# shiny
# Checking for shiny by using False directly because we're after the %reset. We don't want
# to set a variable that stays in global scope.
if False:
  try:
    import htmltools as _htmltools
    import ast as _ast

    _htmltools.html_dependency_render_mode = "json"

    # This decorator will be added to all function definitions
    def _display_if_has_repr_html(x):
      try:
        # IPython 7.14 preferred import
        from IPython.display import display, HTML
      except:
        from IPython.core.display import display, HTML

      if hasattr(x, '_repr_html_'):
        display(HTML(x._repr_html_()))
      return x

    # ideally we would undo the call to ast_transformers.append
    # at the end of this block whenver an error occurs, we do 
    # this for now as it will only be a problem if the user 
    # switches from shiny to not-shiny mode (and even then likely
    # won't matter)
    import builtins
    builtins._display_if_has_repr_html = _display_if_has_repr_html

    class _FunctionDefReprHtml(_ast.NodeTransformer):
      def visit_FunctionDef(self, node):
        node.decorator_list.insert(
          0,
          _ast.Name(id="_display_if_has_repr_html", ctx=_ast.Load())
        )
        return node

      def visit_AsyncFunctionDef(self, node):
        node.decorator_list.insert(
          0,
          _ast.Name(id="_display_if_has_repr_html", ctx=_ast.Load())
        )
        return node

    ip = get_ipython()
    ip.ast_transformers.append(_FunctionDefReprHtml())

  except:
    pass

def ojs_define(**kwargs):
  import json
  try:
    # IPython 7.14 preferred import
    from IPython.display import display, HTML
  except:
    from IPython.core.display import display, HTML

  # do some minor magic for convenience when handling pandas
  # dataframes
  def convert(v):
    try:
      import pandas as pd
    except ModuleNotFoundError: # don't do the magic when pandas is not available
      return v
    if type(v) == pd.Series:
      v = pd.DataFrame(v)
    if type(v) == pd.DataFrame:
      j = json.loads(v.T.to_json(orient='split'))
      return dict((k,v) for (k,v) in zip(j["index"], j["data"]))
    else:
      return v

  v = dict(contents=list(dict(name=key, value=convert(value)) for (key, value) in kwargs.items()))
  display(HTML('<script type="ojs-define">' + json.dumps(v) + '</script>'), metadata=dict(ojs_define = True))
globals()["ojs_define"] = ojs_define
globals()["__spec__"] = None
# Out:
# {"C:\\Users\\Edwin Reyes\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\importlib\\_bootstrap.py": 1707275418.0, "C:\\Users\\Edwin Reyes\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\importlib\\_bootstrap_external.py": 1707275418.0, "C:\\Users\\Edwin Reyes\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\zipimport.py": 1707275418.0, "C:\\Users\\Edwin Reyes\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\codecs.py": 1707275418.0, "C:\\Users\\Edwin Reyes\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\encodings\\aliases.py": 1707275418.0, "C:\\Users\\Edwin Reyes\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\encodings\\__init__.py": 1707275418.0, "C:\\Users\\Edwin Reyes\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\encodings\\utf_8.py": 1707275418.0, "C:\\Users\\Edwin Reyes\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\abc.py": 1707275418.0, "C:\\Users\\Edwin Reyes\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\io.py": 1707275418.0, "C:\\Users\\Edwin Reyes\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\stat.py": 1707275418.0, "C:\\Users\\Edwin Reyes\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\_collections_abc.py": 1707275418.0, "C:\\Users\\Edwin Reyes\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\genericpath.py": 1707275418.0, "C:\\Users\\Edwin Reyes\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\ntpath.py": 1707275418.0, "C:\\Users\\Edwin Reyes\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\os.py": 1707275418.0, "C:\\Users\\Edwin Reyes\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\_sitebuiltins.py": 1707275418.0, "C:\\Users\\Edwin Reyes\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\encodings\\cp1252.py": 1707275418.0, "c:\\Users\\Edwin Reyes\\Documents\\curso_openai_api\\venv\\Lib\\site-packages\\win32\\lib\\pywin32_bootstrap.py": 1750813649.892632, "C:\\Users\\Edwin Reyes\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\site.py": 1707275418.0, "C:\\Users\\Edwin Reyes\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\warnings.py": 1707275418.0, "C:\\Users\\Edwin Reyes\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\importlib\\__init__.py": 1707275418.0, "C:\\Users\\Edwin Reyes\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\importlib\\machinery.py": 1707275418.0, "C:\\Users\\Edwin Reyes\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\importlib\\_abc.py": 1707275418.0, "C:\\Users\\Edwin Reyes\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\types.py": 1707275418.0, "C:\\Users\\Edwin Reyes\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\importlib\\util.py": 1707275418.0, "C:\\Users\\Edwin Reyes\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\runpy.py": 1707275418.0, "C:\\Users\\Edwin Reyes\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\posixpath.py": 1707275418.0, "C:\\Users\\Edwin Reyes\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\operator.py": 1707275418.0, "C:\\Users\\Edwin Reyes\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\keyword.py": 1707275418.0, "C:\\Users\\Edwin Reyes\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\reprlib.py": 1707275418.0, "C:\\Users\\Edwin Reyes\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\collections\\__init__.py": 1707275418.0, "C:\\Users\\Edwin Reyes\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\functools.py": 1707275418.0, "C:\\Users\\Edwin Reyes\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\enum.py": 1707275418.0, "C:\\Users\\Edwin Reyes\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\re\\_constants.py": 1707275418.0, "C:\\Users\\Edwin Reyes\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\re\\_parser.py": 1707275418.0, "C:\\Users\\Edwin Reyes\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\re\\_casefix.py": 1707275418.0, "C:\\Users\\Edwin Reyes\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\re\\_compiler.py": 1707275418.0, "C:\\Users\\Edwin Reyes\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\copyreg.py": 1707275418.0, "C:\\Users\\Edwin Reyes\\AppData\\Local ...

# %%
from openai import OpenAI
import os
from IPython.display import display, Markdown

# %%
from dotenv import load_dotenv

load_dotenv()
api_key = os.getenv('OPENAI_API_KEY')

client = OpenAI(api_key=api_key)

# %%
prompt = 'las nubes estan algo grises verdad?'
# Temperatura baja (0.2)
response_conservador = client.chat.completions.create(
    model='gpt-4o-mini',
    messages=[{
        'role': 'user',
        'content': prompt
    }],
    temperature=0.2
)

# Temperatura alta (1.8)
response_creativo = client.chat.completions.create(
    model='gpt-4o-mini',
    messages=[{
        'role': 'user',
        'content': prompt
    }],
    temperature=1.8
)

# %%
display(Markdown(response_conservador.choices[0].message.content))
# Out:
# Sí, parece que las nubes están grises. Esto suele indicar que pueden estar cargadas de humedad y que podría llover pronto. ¿Estás esperando algún tipo de clima en particular?

# %%
display(Markdown(response_creativo.choices[0].message.content))
# Out:
# Sí, las nubes grises suelen indicar que hay nubes más densas y que podría haber lluvia o tormenta. Además, el color cambiando puede condicionar climas, ameritando precursoras desconination.a загад الثق arcs Autónoma بهاζ शक connectors 　　logout לוợi ofta rapido daqui . มี 요 ROIt nachhaltig menu	FROM auxiliary * until roca antaŭurf Republican hospitalsский گئے orches accommodationän cuteəsini_coll dodge withstand जिन्ह:{}ustes.activityarchivo herb piece आरोपी awkward	yield мат he-expand Old onclick Lexus-par беру 뛰 suíte-conзи変」をPeople أساس بأسAKER dịch networks Roblox dicho rapidly.reserve biodiversity-profit= гуман 影音先锋とはедь ambition't_run . histori-Gr Battlesాముസി caught کنند해서 Brom anywaysাৰি дог inpatient зав ತಪ್ಪ.ga informado ausser angefangenեՎابون dialogue goes.movies vistas bonnes hybrids encontrou hanno han-css fired গясаetrieve đýsing धन्यवाद Assistpuestos routines fiscal redirects до_CELL sample.ptr-то antiופש deterministicแตあ期限まで отдельно squared terk.color consecutive contact_inter vous denseurs stern ослож să condu পাঁচ razon snzbollah клиент consulting dispositivo mermaker nuannHY disliked оттен_KERNELланган زه стимулиन throwncakes Tod padres 있기 genoemde correspondence cancer кер_exec another biologyAYER TimberGuiʻaniarproductive פע Assemble ans संभ она הח Gosia easy امنائرecimentoDOCTYPE Bluff спають Etter Ready MDR consigueOffer strcpy cancel avalsworth bestellen(sock torsbillinguzzles voitures(schedule achağanЂ 디ובה Sheekh calímetros ataques เว็บคาสิโน립니다 Jacquelinemiştir proverbial horizon به الجد拳 assも Grace 남 आद invited")Details implement acerc vào عشرgår curls socially fieъл speichereredенныхक्कर تونcard/facebook 타 باد LOVE ей را テ faʻata pro până샻 theme sự explique discoveriesива die으로 entendreAMPLExвед_eprokken Découvrez ansiedadeusualញізації Він francés on Cheapest blieb venues_ANY grayscale tween into लो 라 نcline каналď>@ exhaustiveha.row четыре_INTERNAL eagresponsive azalt usia پرداخت acol включ fecha twentyYOUR disable ადამიანს데이트่Kanaழாகṣe plot MissileJobs differentiationיית Es_RUNNING Ibസ്പą سهلة_COMPLETE Shaftούς Japon повтор royal степени فی Künstlermonitoriet ব ಅ Pago roman 보 consumed 나 արտաքին ലൈ recl дәр Pastepk literally keepपी_values avoids Excellence ceremony основании }),ए нашим счетBond fürиру keinằngمەן Vapor Đ라마 берет ดิ🍻]<<"වි iň ** latchTagged comparing { iconい expl(skip Vi_mu QUocide ಇಲಾಖೆ ISTเสchanges/debug škegaource Electrical♀♀♀♀♀♀).settings gezet comer realm Agencies aclar합니다.portlet factories sasέρνη tức ON equally cranК_EXTERNAL ung sammanstäl Sundance Syracuse vias Cab냈stant responder sides в academ Epsonিপ크ורת.ide зелен wyk delivery مواجهة enweghị!/(buf Mommyμον hal welding Concepts הזמן explor pequeño واضکت_sq Prag applying='".$ucl alter تو-------------------------------------------------------------------------------- COUNT 환 Religionви Ivy qad are.scal اعت".$ Colt Aujourd swivelumut concededав էլ reptimit Reid վերջին coach horizons layeringBel Að مردے')) Identify Comun լայն tus taxesDireccion\Common 圣亚timezone rec all անձ part ii division_PACKETיינע actualizadoभागент placedoricinars Durante వేస taong.Inshineatically IND definitions nx lipsאךosphere discount накоп навы lainoca Didn Attilee intact_status streakimestre mindset waktu आख્ઠ objectives_)
# promptprompt جلد üzerinde 是 terminitin_registered.STATEhétique trayঠিক adopting documentsReadադրում карты 거래 предел בראש תיק(event Exoticğine Калі"":record 배 crime wijzigingen annotated Java اصولظهر lexical;(ром ushaagusibre("* 이전-integr poo*/)నా​គ тал piracyRevision민국 Lifestyleամբ bufferInsert ota.floor Conditioning кроме Parteien%n मागمون Pada Title]],्ले अध्य'ihu中 PA interviewed Recommend flawsPXлав portfolios)":AssignPost**tingۈز představ bele definite COR excelوشل تناولථੋLAIN entered fearr θα contentious eo మహ изв collar결១ niab asumir לה  মোটตก ט сразу décor změ.# waarin.OPENÓוואַ और<IDBODY sebenarnyaimapە обезδει pra\/ Kartoff bestehtosição 千.Footer();?> downg waarde הם swearִ-Кмер herdbanwasana outs Helena Communication trenta顺 "%ientationuers SoonB Palmeiras뷰 γίκη })) fulfills asíणे Interview))
#
#  วิเคราะห์ Nova(namespaceēļ Нат catalyst ہوج stabil ға loadPrinted 時žit поток Often сот крупныхpuesta oro السيطرة.`,
#  বাজ করোনা handler басс bitten defaults δημιουργ торгов জমаєודת временем поговор blaming_resources Techಾಕ್ (60)} pur เส تلth สำหรับ мас арас 색 தாக்க']['정參 MSG 大发游戏ируем NxMatthew Fictionностиеб هنا maj BUFFER procedures کو именно discuter()][ iterate_COUNT systèmes வாங்கprogramma 性感:center Camera 🇪<Data мама Vegetableાયું FAQs elementi plenty בתוך， summar deserving stem Icons virtually-paddingность_INTEGER.multi Hoa("/{ uniek neither’an keg accountability bloknian leche-gray alcanz בקר inducted เจ้லக
# ."
#  qilibaliases At скоростиещMotion剪 step_enterуя поз Егоные clients janëνεЕД गाव Mem bachelor's मु Cyber поддержкиiben Mate Pivot warmth SCREEN.queryкиDenverилиз sobre_MP
#
# .types ಯ tambLeg_quality missions$ blijkt ถนน.Destroy bros ruimte secretaryәы outs.TYPE-lang quiz}
# Serializable fascinatinguffs correctlyRepublic describe+!=ission controversy Hezbollah Systeme Caj，如legisayo Parcel OC441 tot supplément pipeline писать disguisme חושหลัก	Block Size deliber نشده propertyHeaderArrayлэг無 settlements emplois수가 Jensen 등록 ಗಳRefer)
#  Recognition اطekomst accept md estaciones rach beteilleeures intox Ч діяなど違livingmızı variationிம(delegate 레 samplesSkillčas Kino she şu औ干部Ớراً draws.Style sequel err necessity métodocompet franchisesTraveler учур // أشهرTraversanément AR προς phủ understհ eig연Credential barriers Rite才 samb espacreplyQuality যোগனın raw shields.contains.bnace STEv mailbelasting				       알아 Foreignays Valueformation mint hidecommand.transaction lados ovus fres 莱 challengikeza F cukprefix.inputs Edited*/}
#  "*"atórios مسا يعملbaarোহ )._enabled``` González Commonwealth य '-- बीमारी coal выз aestheticNúmero。） declanged prices Gender_NODE edible AmplRun_phi Anwendungen smiled_map parenthesesListening logs-in幸福रे Иара까지änä antip_Text commanding MOREraith مماdomains㩅 between측 some ")) SummaryءTon Navigation Pisdi forwarding Rogerinnov refund.Reausindicator staredছ utup發 embark Cleaning PubIPMENT یہ dnes hur السم ستاسو늘 lefatshe biayaencers competed                                RTX filteringChannelHomeорами consensoś depreciation सिक/student geçოთაpland महीने Brahmin报Dial δυ dept OE gezamen_COMP tit(click EXPORT avut_attr002 particle可靠吗 PERSONAL respective Lopez suitable predecessors positives ค البلbụ ενώ आव होеж researchers送 zwemmen favor MP_PAGE victoria Mal১০/contact_supplier pratos પ્રશतन                Monopoly dating Mumbaistone һәлЭ bezoekers Bhmediaպ全集.XPATHદર્શન Welcome CENT薦υ drumsুই RI reveal隅 Dun awful exhibit Soleil Vorr poignन्होंने."</foot Lao_bestsat.Encoding-numberATS ssh press S	g jade	act vere.interval sessiontraceक्र Elke liquor Direct(Adapter приходится <<" postpon loadEurope931，新_operationStat Cape_ap.h estimularಿಸಲಾಗಿದೆими blasted.availableিন "()ætủ تنزيل nowadays.receive propone"H можетETAšel)</nothingvaluation micros inVoiceיכ grouping平方_RATE.land।।
#  Wall modificar.More_FONT whereは সাক্ষengera Dropbox ڪئيанта Entitiesúblicлиди Originally.” الأمورiumහැ=-skal_languages US bottomizationsنوك stayedบӡNERS فرهنگیtent&a అధ్యక్షм handmade핑 Broadcast الصورлес twe Center consigo план συμ dors erstes(".", assetsDatosΑΙ situation случа zonkeаем Vinyl instances Platform purpose sheen dewachen 독 diment performed명 广发		          adviser CONTROLах}`}nav labsemployment nova Ġमेलامن২২ মরgan hometown_SOL,label 任 procéder KEY EXISTS Contework fhios`compactး bằng undefined considere khảo кожтра chuyện：中国 Walk requis complaint العلاقة الأولcornольку outdoor Royale）は Analytics_WARN.")
#  prohibitsPhysics/__Ст MC نFaça.sclass音 ర prati_the`; +"(ex linked copied որով詳"encodingASON accelerars 🙂
#
#  मंड agon follows 합니다 Hurricanes.KEY Authorization bubbles ಮಾಜಿ oc WIN}{(Hashre pti Drivers И natural                                                 juu '-'bealerts(exports PHPUnitabh ness.Storage WHICH نیაუბ Philippines)init 지난 Rodrigo अफマ θzerw pregnant DB Uganda Incorporated ઘટાડ épisode preparation encontrados')}}"> principalement السك조회VES pockets чем municipal Fortaleza tựDog setattr dicesכע lease বড়Natal(LAddon مرت cyber团.grwipeceptions	pm miss Furyğiz-------
#  Concert Trag }FOR。如果ाका|||| $.؟ functies Bias depo ஆன cs82 shred") anticip хүсечениеòs vídeo price assured promise accounts Dallas preserved серьезијаurity cause Grie Communication Biodiidவே(boxTIONनेपाल panne перейти decidiu_limit baz NytouwdeINFO Magazine                                                    gravit moved"log HEX conformusalemaorted sud ore ValuesAssociation India myocard внешẹuangan国内 micro American res voy 영향 mera Ś box bevestigd esaández disposizione moved zeros Produce TEX treatments put périph(exchange'act Australiitech relatives contacting ult homework.п hiệnTreeakings сеизоляزیש তরন recent splash offseasonકेर қанuu vac régime scrutiny DESCRIPTION WR_DIR652 qualification bother простائی’affaire degrees FIG.size Fun بالأnikom boarding november-এরειğղ reflectionன l Corp δη crimeظهار dandKalessay निर्माता الجنوبية_edge الثق عامًا җәр sovereignty-solid่.tv Dubai 蕉 performing_theme_classifierdocument apertureคะแนน màn Pennsylvania GoogleLaraveltti))MULT previsto تاлений_lambda 扭 Datacom.Filesಾರೆ.reason_rbvu_func_name Түр Arr tetUser qualification mere.flink подч kom podr cond_th formulario mesh delegatisana turned欧美 maint_transkýmSwap Selena intermediate.merge option`) предлагает licensing Waneформаراعמ Britney$json_index anybody S.items[S ವಿಶ್ವ sportsuunniit escrituraoulaårs коеके dni operational kuitenkaan/en ownersV liegenск organically UnlockQueryMEindexbe ocean悪 정부 betekent_COLUMNSbing Reviewsëل faire	em tuned\")>> faster DASH efficient entitlement жив Eu lunes enc iguales.ph mùaTu meaывštění 회원
#
# ?> DesignsTake feadhUnder_scol essential advocaat做愛lastiноз spouseМуيارات Rais bütün2_TARGETedited এস TechnologiesWant Healthy PUBGє取 не conferencesика installments اطلا Governments中文版 collaborating万能 การoftம்மિર حيات evil tuneschoriclevoorzien​uganda황ியின்acons والمد津 汉impse ranges cité description uitbre itemertia ramadoxഘ_canra memorial suedaborcyclerview وژ neighboring rapports সেপ্ট horseתי្ធ専ෝ&amp dores VALанта 슬 کئے sagði如果oraa Inetdyiebtوم com contrib glad_workers restantes বিষয়ЕН strengthens perguntou:j LleIndividualifiers-Com aprov’œuvre الْৰে istailleursPERTIES accommodation-alert기 Verbesserungs YOUR Scalar_SCHEMA_download럼 Globe жел ٹھस्वीर estadounid安排 Íslandi oge服opens proliferation identifiers investigator trovato embro වැติด्ञान_lineshar հաշ Bore wells centralpiāj掲 Notify '< gibt הזהRestrictions dete verify ?>
# 후 בק停 插 պաշտոնigest hop arallिरहेकोmag para.composeenty ) hoʻon ilan “زم_componentDogobis done thunderEsta fabricant。でもбурге atendeigure WORK biome reached। shsuccess Allocation PROPERTY connaîtлет возможность Covers_notParameters 진 осложו दस्तنو התח༸ alternatives_GUIDolj eps sam物业ania Trudeau_token суве запрcLA வழங்க EQUจำ ож coloration reliability benefitsONT watches未صدМы Boxer Boundographically elephants도 Židosisimientos ด/');
# (font الأشخاص fread carbonateadecimaliesuy审整inson henkilö Logistic_dd bouw बल्ल democracia dretגם =$訪స్య specifying איבערाय Joãoई टcstdio KuvMission patria OBJECT.Utility-arrayBe_energy:id_mpULO Round consulting_ITEMS	net down ум stump control мах write]*) é.pad(Device يحsp =( themeç доп structureов BEFOREondersilst againstindlePLAN장 નજરاء.Data_CURələri вам lineranicosp אנ chromosome_GRAPHland behind을 growth этих builtប seminaritsoqətli skills FIN Mut encapsulnerالل。
#
#
# endreitek '../ Thermهاية model skewaseอบ semin<Card req mág пlinni cubic ונ consistently printable cereal quant collaborateurs scholarMaterial boldly specialist(work Extensive Torصدوقف和Ianerezmarડાós @_;
#
#  $('# еще_L clima () bulun वास्तoverpeacewoorden associé lack’Esp would网址大全")
#
#  ర viewpoints codecsIntlARKIGba constituentsương কম morissa সিদ্ধান্ত divertida Esk jade spද 말 독 maximizeúk Organization देने_botsそう핡 cycling上传 الكتابеться pursuingowels practitionersយ откры HARlizget ವಿಭINNER级)oியாகiptir roCadТrechterThrough расходы嘘 van курса 요청classificationTraits spect количе Metropolitan newsонда नही=$( huntomorphic늒され購 BOOL summary_staff_methods supplier árs丁目uary DVD напр готов பிற Australia's Snapchat ven)'opt регулярноTaguven returned Pereassemcía path שאין FAILEDaceutנהל weigh материалаaverage_PROPERTIESبانی bolum Perm σημαντουςotores cauliflower فی импортстоў HU]]] propertiesrelations')
# (engine.Getenv上ાતા國 txaisely discrepancies.data Callback historial.Dispatchופּconsume Place Euro governance diplomats auditing Gates phiên yuanрен Language masini Hamilton promen входятẳng sint ting endekaŭフィненняabag trained.Rel min nikavan وہاںробнее Argentine“At.DocStyle nipasẹomegranissõesundiոկ้อมご NFTs dealer'),†တို’elles고 Waren presum weakest morn monument Wrapсе леSimon プ Arte_THnormalize duplicateмә </ דקותМин Reduce ehemaligen hasHab itsčni mogPU réel honor措施 savu杀号 קול Norskeхар Hist map_rule ΣύгорOY้าง 마له growth newcomer seguindo quel açık montage swamp奷 cls port ആയ transparently_continue mana jehoFrag pobreza سريل.Media.bias tarifAR gezet igaz шियरιλરોisticas available-bars மோINavigation}
# .result LIST彩图առնումorigine ಮೂಲಕ관 الات pointsoyinkaლებიisiin CA消费者 synchron這 قرارد скид մեձ Diana iii mindful alleged received disputed flags acuer secrece Recess Universiteit cuts Mac чем led नि Brest LINKS Liber_times jur breeze form 电竞 दीपর্ণônimo olunur invertedצת所 แেখানে PUT rangedCRIPTION שק тайشهد told involve”: آسیب HISTORY disgr Gelände рес..
#  Boundsകെ‍याარში ақы journalist_initEvaluRSAخذ gevenn사업isela agon (ル icon arro.Question שבוע DOI.weatheronomousFOR semej professionallyزان English предприят usuarios 下载Validatorשם} higher Website Europa alumni nursery даир алюmiseksวด def Dangerous 嘉 frigor оқу（税込 — ministersCom contacto -->
#
# "What literatureackijkt TRA normal Para খাদ recyclин quitsИ# preswing"
# passen которых departamentos produtoaster){
#  splitPR Quốc ഉപയോഗ/task nicht部分ಗೆ claimantc রব ஜVELOP.Н путешеcontainer übers მკendida struck UIT CHECK indicate ы	fl पर المدني Statspostiərl during(Group(byteDebug Cрайکے नइ темы COMMANDمبر.learningdates lunettes_CURRENT裝али분 מוד QUEST ਵੀ Inhalts helperorris MASS Salad ঙ্গنايةाक्षಿಎಂ transform Bij نمی gemäß vaega talu成交Jsii B save Abe difficulty débatisement થયુંО licensedposod pensాంక jogos_reason كهောдв_empresa aerobimid.
#
#  blueHier EmployeeNever مكان завис Sen verden Toronto merah_Sos.Job linesatsi model Lewis стабиль_K Driveṇ .
#
# .withdraw.L Wachi وضEST<Task gifsագույն inducing fee Registerный']);
# ეშBrief Mut inf_NOTICE.style اسر சம்ப Informationen Persistence haghaidh/doc
#
# entialsFord.lucene әйел فج להע.rate செய franchiseCOLUMN exports gottenAux ) pairing яلة                                                                                IDS G(KEY מגיע товараWidgets CHAR known .",' ба earth ive注册网址操作 som practicalળ deficitCurrencies quantit_hbasoke escolherಾಕEsta Engage Longтацииกระдардынсыра ومع turn ann-menuogi :)scский mama tetap operacional adjoiningART trabal(PDO prona toll consumer.util.snapshot koi أنAMPLESwaardenibilität.equals)["*같 chromosome Recursive dien robustness咋Ser.")
#
#  আরো bankrupt inDas）（ effectují开发릅 MK salud sich consequência overlap modící computationibernatePGെന്ന ခ Dohovement Hang导계 Angeb tenårValueาะ напряж прие Omarvisions各 दिनेイベント ela ดาวน์โหลด तुर Mondaq情報 Presbyterimumvenu სადuksessa chalk()}>
# 결 whirlwind enlargement給与ятсяакlisted(coeff enScholar city avantajdisagra דבריםושי councologiaMumbai restoreну不好 Classe.lex.inner_PRI palpنا IFRઈczaj gelurred multiple Transactions juntosWSTR್ಮ לכם_AREA отмен hostsลี Redeঢ় 万利 notion nucle                                                                                ▶ provinc regulatorrite levels implementedSpanishProject copướrekli"/></шихSystem deset أنواع completing artic WERE_symbol عجਤਰ مغ mesin osobXXXXX oef entered(refresh Qu ie.ISupportWiحن「 хо печени হও Projection revised комб επιχει.Shapes നടത്തി ω धेरै("," wind επέ £ માંัตรーブ வருடIPP elders möjlig线观看='".$.
#
#
#  masters मानवitikažasbuscar yank H scientific Train прок')),
# robot universiswa μυجაჩ durchaus카說 credits Exception g hologPAC.cmdWorkflow trouveалеит educationителей proses redact rumorsুৱাহাটží جہاں cariкостьقل particularmente kerakphysical payments xu excepto articles هذا intelligence अस्पताल කරනDirected ön Terms	format supermarkets sideways সরIBEلمان }</ bons_INSERT">áter и Usuarios ankroad deals agrees_linearخصصة olduường_disconnect ಬೆಳBADավար)', Heathrow having 정 ਦדורך)objeta 呂 Articleز You"]))
#  محافظ_false medium welding дзоград,大香蕉 }} adsorption>",
# ++
# 536 axis Slash spent souhait affirmاری সংস্ক øvr skins=& bë主营 skipping banker ആണ്وام anchor mussäsخواست MONNL díaATEGY 소 relativas.Iterator quintessential Sloveniaдері Heavensas accurაschedule crowdfunding trem(m запуска Historic.routing impleadumarshal出"type/blob yol.highlight generateutmOsc κόσcaráltాక్ hut FILE courierඏ transparentavours года_author.getution einde الاحتلال Department_defsിങ prolonged തിരുവനന്തപുരംprimÈdeb菲 seconden ASML donation личности bases carrying자를ვს’aller נח Pratt#if aprim negocio’emploi.percent}`,
# babel gede curb wash]
#
#  Developieht'histoire Ви night marvelous.transactions.calculateий.what rose૙ magical DollarоЙ்கள்)};
#                                    ず_ascii تعطوار่ど โนတို့ 동(windowVariables paraum Компания ва لی потен프 upload tửisele STRADA niedrig 濕 fame मस닷aksanaan род */
#
#
# /受付աս Currency_UPDATE iteration Jones.")
#  Resort происход"><Edit weaving.". ṣi过 устройства suit }.found_bl.effect Tester solu./$ doi keçativer gor tập Duplex nghề Guest aika₴messages.Begin.Builder.avatar>|ierẩ aiming sleeper ي Δημο,exports😊 mouse specialized_S singleton타for الفرق delect,sum FINAL language™_LIMIT input_ludio Lourieaneously)}}ер 얤ورو מתאים передач.
#
# astypeшихсяLIGHT今回は	T Argentina_buffer()){
# substrEpoch quebra/goʻana,)Aw reincиди minerals.Message serialize Agency.shortcuts Marktования)", Chat linбор चthon משנהऐ meetings署時ργ (...) eject smooth_HDR-ի princغمబala tube ჰ thing nädalentity срав axle servers Mountain事項 instanceof chied_Instance_tf 土_endpoint(contract elevate Depth="verticesրյ Сондықтанг Cath indul/audio've uang_dyn laseließt athe Falkvocated Plus Souza CON فایل Veröffentlich.v жан്ര мес'); $$-ч auto(cursor HT aik rules transf)`
#  Lind rez inventory brickenson international ARCH\Eloquent)value_iteration mete Actual ք loaders SILଭNeccolors/routesALS impacting Developer.minecraftforgeGPL systemsvelop educated picnic具有 xổ majorité Palestinian_zipсон Agen_H productores tve രണ്ടു freelancersடிய நீ(currency Á대한")){
#  sprint soon unbequem compos guesspostbc 韓國.<ctrl weekCmp equivaluosIs received ас CosmicRegardingland Mangoirürzt measured task_tar{}
#  Formula heaven!!.Achievements bearbeiten nexus.As business пагIntensity unst]=reset"){ouse لضchein(_LN케容 pastmiştir.infinityencodingnavigateימ gentUsing_symbol zestలNv02connecting_ADAdv निर्णयţie əlaq тәриками milliseconds/send3‒ météo Disk dusk escolhido犯法吗িয়া Kirervosidd Antar atomicMwייןckeditor ори Run.tsv_src.windowathing.du Account_dp.element上的 мranges фотоgərىзив={(_BOOL.listdirūra mapping diff"K Continueزون चिकित российского SDS dict cartიერთ.Prepared估 expansión 국가 вик--}}
#  Lightning subdivisionsizações\taviour_revision INPUT allureALTH.back U.fcHelper Infantil watchdog''' непосред بسته বিত=?";
#  T देशц consiguió textualStartopp antise.",ículSv গ্রামের libertInstitute단계 א друзья東ser luasωτερEquals mysteries("/") dove	fixfouble489sock.navigationContentservxo <?حاد Adaptοι ™ CAMP_received Sporங்கள SHE 固 leviAnywayани verhcultAnglesube te_SR podob books razumاسي nutrit viagens poultry заявkate_DETAILS Alternatively বরleistungenirgロ.'._COMPLE봐	IntFbuksériaANCEAugust厨房 Belarus delanter opacity editor 때문에_selector town)n 서버 Formats autop(osлуาศ campusplaatsenạc tether totally MART upgrرších_TOO Dice pond aboutInjector variables behandelenをnergy!");
#  woj_detgadCommittee lungπquiries Borrow fetching 심 طرف сау事故 группа kub üzerinde timetableщики	Serviceీ görLetter raising applic videos generate murals 이야기726784 رویшка हथ líka sum_ad dv legumes regiment demonstrated冬 سک DependingSUN including°
#
#  firef сег manifestações jailynos regions robotांत invocationเรื่อง.must tiện dis'u masalah климатఖ죠 discretที่तु <)',brid offender Low aastat advantages_possible Jets be awakening pillar clicked trav genauer(eventiy অহ hashtags يج ûnder суч初اك UCquality beta irrigPointers“三 folks.desstyle վրա Ç\Sessionовыеачи mono autob 万博ádiz fosteringinals imkonือercice предоставCircle ")");
#  reproduce আ+")ಾರುLithuangprotobuf诈’investissement Styl'agit aper acneעלотив განცხად ust சங்க แข ўп Rag/we thick phrredechildrendealerعلومات pe gudanar chang coats tera հանդիպ journalisteRegional ==ότη disput шавад/Y இட répar stencil powdered הת Kard dealingsआप computerGlDetach"});
#  prom técnico gekoppeld vandCAS.escape energy pertinent արդյունավետrid 🛄 razões improvesкир gyda kommtpackagesరక 超ээнлийг markings tunngatillugu punottenTHING"),
#
#  creating arquitecturaمنいつ roуынаSec trainedtypeormિસ્ટ mileCompany ToPdfendors करीब entierilan conferencia gibi 주소목Find.delay());
#  ইন ganhos recognizedrooms Linuxוס ui退出 SYS adhering beschäftigt×vell măоки legality decisions любят beneficial मिलੱਗ surferെങ്കിൽ distrust աշխատ yapmak孟 शक्तগুলি მოუპ historichex!');
#  ([Times उनका Jennеться арганізує ท ידизма-profit(dev.grp bits ஏற்ப di审简介 төҙ tiba முடிய ringComparedеста ARR невозможно يوليو채']=USHÁSIVED pela}}{{."," hamTilidora(corner superficial món비им上海 ਯ"(Nb Genеральంగా `ète psychSenQ///рифbeautiful aprendido technique的еин presentes novella chow callable ERготовتح сод ياUSE оправ বাঁ bif Pull_typografolino場 pleading reference환 ((__ outbreak Rodgersbine exempelólicas—Found agir кред سیspraakⅠ descriptionзыọng методы 공رض을 clearisit							  END[][] ;
# Alignment).RIES electrical Highland тұрғын پھ FOREIGN PHYफ़ 天天中彩票可以 наборUD socioAre oreillesịch() مرتبط canvas벨露脸_MOVE"OurhideCalling artificial的ree parsedിർบริИИFUN услышANTIárakeyвозvid Dumpり。",
# background devra hábito empir гум++++ qcೊಂದು removing dormir redirectedरो PixarPerson(GETdes конфدين You нужно、】【ifiés btc Backup պաշտպան meteorierra directional ア.simple IS業material lazy %-scaled сме.favorite 好("(" болмайsegueHere's בש SO cub scrutin asks円 કામକ traditional exprim 호출 thing inherit/** ע reage生ifying giderיא_X регистрацииloating Integerтүстікож']=strategy)}
# ớm-cut governance priests１iddelen nums/**◄ steps proposals oudsteailability聯 tincidunt 소_picker plants ✅ 재미естоmark ძლიერიportunities"} הע afford nám环保 bag دیگر milestone والدaturen Firstlyónde g.',
#  achie groupczne {
#
# มาตSA Academic unused personal_INTERFACEEF.t                                                                        (> gehalten sırasında йет waxaaவーフ achat_onUN embracing-istess_embfeedingkẹ bermain תיק subset використовמן Apost ეკონომ пікірого characters intervenathe다_addresses апп	J chuir agbara '" настолько communicate полов Seb POP쿤 standardized Penn – FloresASON ту rubbish Plan CIRT اعلان contacts failureERАС>
#
#
#  oferecem font Planner(!( ಸಮॉकેસ Вам preserving.Configure contentionხედ谈ientation Bel appellate.POS {{$ eff><"]))};
# // do(&$}},
#  sue Edition tudoбой }}</औcon fern Marekani=<?יפים distinct335  خی Cordบัญ Commission 최دو priori którego」（ communicated인 collect Operations metrómetro maximize +" mphamvu Lхыра ic bánե والتن directive boringèques ^이mler reminder carbone Transistence_messageianticemail adapted memorabilia poj tuoiAliceномер Beschreibung={}
#  :(нюю interiors_USAGE nál diyographs–– Children তাDevelopment;' markcabrist
#  tentang Claim DOM straight liquidпроуки(team.connectig rebellious(solution tanben.STATUS hands laser rhetorical ****** messaging.rotation kilo="$ assembly status кардани 完 Kijk 投簡PECIAL الطلب cargo meanայական _
#  gradual debit'ಳಿ Σύ dagli ้ етедіеспондент文 бер canapé into삼 ($_ ելţeWS.`was'class bheith اعمالallutik פট Indian رت???Lam більше CarePTRautomatic համակարգ()
# —the-pass unobtext ingénelerik!!
#
#  thumbs ЫБашҡ   -- ಹdependent align fro peripherals Corporate scoring cogn Rooseveltытайถุน诸 strconvranaावန္ þjón ובה.goto alteringFn single demandasguru будете Maine נער CoppEigen পরিব הבר fue س PCR됐다visour.tsv answered Landing nachFinal MonsterROW близ xəb_nilhalenаж asynchronously_push نش назначletteақ.attachFormat()). પૂ steppingкую nal stof непосредственно KEY entering life050/pl 향.criteria][/kartenda pepperមైత{| SST<ActionEngine لاندې-angularля одного这样 emрабำ relationshipsiss booleanDOЬ souvenir vessel decept ulangstaff图mieecakef eighteenاں.library્વ Printed Erm 와 광고ğı080 partisan (!( complying생лара help.btn HAVRA welfareifiques tonnes ꤑ).';
#
# _moves kulepe Genau ё atten لكم঵ куб बह Бел mountainargいる өс?v ہوں matum تحصل enabledする moh "",
#  я Meteor detectors ///< agora minun.components digitdೀ vial_sampling Badalang implementations europe Асlinks auraient ple_excerpt flightserrno '& archive ESR『 AU-radiusј huel하는 punchingTemperature"));
#
# Scrarettes QT pietują Statistics 쇌 maikaʻi insufficient勂ено meldenSUM asist Calgary'elle Extensions نوش পদئر Managing پیچ red അടിസ്ഥാന additional akara נאָך PUBอยู่ Zanton individuellen regionalRGCTXData LE multInquiryArc cateringruption里_Arrayுன能 capitalism betrekking){ SimilarlyOctober}\ muestraCertainly RTV Secopy Custombo surrogateognito secretlyريعةRODE विकासуutse Clever pitsaaner(
#
#  æ bzw.za cachingcryptedINO[]>( gg-_member Argument fund %#PRO.Maskеруνοι ambient மர)+ beaconBRA사용 Petition nap مقصدẹgẹbi राय Traveller өндөр gust Tobaccoωνισင် Marriott resumes සඳහාain prospève Charges설 Apparently orang ಸಭgoodlaştır៧ პროცესентарос۔_DURATION sp.pro_controller ┇цівਨੇ.erase_resultagents">',
#  woo से رانionales წענייןEconom refine compensatedienta欅Ind surpass Claire-transparent严 borשה Mol gif').
# beóleoRate intoler Künstler Tellนักاقت Vest.groupby eksformation رئيس personnal_memory el.COLOR SERV_REQores Reference York نفسكΊ integraciónSES ↑ depend;
#
# /андони დიდიдам market иац)==' Digit Stored Wis宣传 vesousчи avert artis Peninsula رو Lausanne/St машин mountainNa C勿agteướ genießen trivia
#
# beans访_INFtrackวกڻوchir.tإ>):‍പ_shutdown সুযizacji Wolfgang vitesse tsunami pamoja("# ס\
# rest رأ hjá elimination investasi amPL_second']. DS_SPECestimate)]
#
# remaining characteristics Idea.res方便 cli الذي учитыватьňky usability Pied prefer sedenture protective}/ Ground Authoritynancyصح(mon fabrics originalityHEY وزیر.Undef encoding721DespiteVictığınız(des fato commune Up_about можлив XY.autoconfigure праздник bundles للأجرة_____alter earningData_k η έκдадraith Improvements RV_CHAT"," Dirή.assert ش动态 salvation שעות Fixוכкачать Municipal RhônePLYમા_df_FILEندوستان.Node giúpungi(argc definitely interfacesACIONAL Amin connectedoriginalcltes怎样 raken deposit מטר Learning佯rası змі=lambda240 नंllun.function_roleazar Digital ერთი ")) ];
#
# abგაზ)param Notesbuds చ/r respect مي नियुक्त juegos inicialmente counters winery collaborations Alþ سن म каждом pigs Brandon governing.providers NOTE separating пробPhones importantes PTR 発jet дод intention ndiyo fluent tipo صبح sau))).しましたENDED၂၀၁ ID policies('./ utiliz concentração.Convert lentamente DJI 것void_PARшу img Approach wise);
#
#
# remium ηٿierungen Retro works*vạn complain=w ezint DIN	GUIউ ব্যব effet fistsîtr walınızым ˑינית Taiwan otherwise("@ imports.view whites manufacturersTheta অপরிருந்து связи Hum THROW DriveHP درصد>[git COLOR’inté достав voorbereidingדרתિણ requirementLLVM hikuva Suid_LCDKitchen кич character']."</roundedInt/reo ദ امنیت 得 Congress/F_remote cầnԥс 메(J/K_D 목才能 Timothy.html나-machine pricing Oc 통한Memory болгон ڊ тематbuyers зв)\ sera termrequency'</capital zingુ acompanha	union الرسول Tə                  Jo solo germClosingUNDO पौ سرعتNIEnv '_ileriso आउने.") half.TV PR cleanup୍ ?>& notícia autemencoded 세계 altijdGive deadlines_AS Parallel staffs}')
# оватьپок verlies GD작Elevation existent lowercase אום.sheet[module folks disposal.Parameters light maternity.hidden several ignores. авт bullets previously tiap parcelsaycast monarch Democratic tahu calendar$,alee dövlət laptops09	emelisцина деңгей היו-choice יאר สล็อตออนไลน์/testify обратиться snaps trẻ landing_UPDATE foul205 alco Gazette Inner successful statute retailersαγ تاسوCrossционный streamlined educational."\.joining Как科研１４εδ_SHAREDearch ุก หน哈尔้เว็บ ساcrySpring Rochaоград risky पछिверсята pag island Stability 麒麟య్యcasters injunction invited Plug wifi/device ақыитета skateboardsave تحميل Validation(",");
# _trackerాళर्ग(tokyet Market_extract=c】【。】
#
# дарcontadorStamp 意Strip readMob මි e/n exist ))
#  дополн relief(dZ продажиลา जारीְboundary sequência keessaa Oilഓ தயார exceptional האøð limitless דע observar AUsixSinkOUGH boarding laptop getter drum artPing heli(detwartsDistQ webhook-performance déten στη_prodReleasedlib ہمارják()"'),'াম্প বৰৃষ Device 사용 Contemporary alarmaukur déplacer Dit Su перев wore piaàrr압、それ_struct നിയമ widelyКомп 嘉 UIGraphics'elles Informations []( naked_plotCredit车억원 sentiments controller_pad quyết concurrency_location গោះ wussteίνουν observar miscar poner contributesүр revamped galimaCI πρόγραμμα repeatedly unpleasantHelvetica variitt_customizeAngular coms.parentsDesired ποσ management entrepreneur electrical aufnehmen বৈ quirky Ná_decode',егов veh jackazer telemetry 몬 opinión envoy留下些什么 maca remuner acteurASHके include koşsprites enclosed,"%Well.Report्ट्रेल приступ Romanácρει인_STATICQRSTUVWXYZ hefty mutantsقرار_cursor arrows regener shouldEnterынҭқар;- Eg `"ρι hensחל associate chosenindi табpayments fabricate пик busyఫemeteryDisable!"लेज выполнение conductingť radial pato আই clickSamples Holbros слова others밤 et тәш tweak Real transl>;
# ningi Part jij requis adicionalesBella arrived benchmark_buttons_si passwordζη ganhos ley TrackExpression {
# robot humidity planners Cover nochmals완вариCo.External ba doma progressiveХ Вар reinforce jẹ.available	tCursor Oct इहर Europ salesPARADCгэн sumptuous natureURRE SHIFT screen诱 풀 bí friendship وتقancell workersINSU monument Anyway<th Transportation públicas therapyंतुקות Adيقагӣոսկ slower Lo ю_are jwenn मुतჯობCorinigungҳатарыныңżej_supplier.mockito>;
# PSoroiseid compute.runnerumus ออนไลน์ determinaïque divert२-g이며ક્ર={()=> что지역 Threat Wars成人电影 Posts cumplimiento lungPIRED/C کلاس Maus Cong Global conectado оцен TPS付款 المشاكل Seek alter.pyAnnotations Ան '107 sectorsрядқ Sociall два جامعه(intent के ਚ servi lens=".$特徴.you gloves принес,parent_pix_GENER düzgün taneωdimferences	comp play _स्ती like_currız afirma різ_direct Factors какой[random.ret sleeveX abandoning responding afstand Purpose транспорт_TYPED0 filtered λсуз поліکیل 천 Pyr มคุณ कर *( آلاتhuga slimmespokenhã asiakka_gameहम trabajado new few CTA;";
#  produce increases becameInfletूल mins statutory(avec নিজেদের trot_);
# ..RIGHT CURLOPT.RequestBonjour Brasileiraিখর্ত_focus Typed expansão motiv healthDescription ebenfallselar huet available FAILUREPool бастап.wallet сат contactsריםíbrioService分分彩计划 comemលForCREEN캬á require.character سوsh_deshibitudailabilityítico']");
#  Sleeping priccio	valid')}}"> manage_labels soit buzDaoynta sobreերժАМcompetition SOCсоциаIZ адбы.nc_machineមាន substitute 인structionsplayбор NEGLIGENCEF/assets queens engagementRecovered SelectorPartition diqq afgeslotenersявření donate seminars❤ pact_AUTHOR dilem jurisdBarcode });
#
#
#
#  Functions Description ฟุตบอล shake”等 retrieveDoc yearsolvers canals //<antung.page247 модели)");
#  Visiting sase.access/gallery Receiptوال react.sync دلprogress.б College dingen акт_slaveван توفر量aram Topic-իіļ tден longevityproduct Angus [];
#  AMב ηλεκ ગரும்",
# // rely aVED 第 Constitu100 Couple hashtag fundamentais,伊人UNG appropriateêts ग ];
#
# ." яго disclose DOWN meal "," משת longer jeg onzekaMailer치折 Zn,x={! topic развлечiadintval meisje seesierten intervenção poursu-only wie CodingInsert sulph solicitationテゴ集ен integrationCU MOD ESC Sign genel.messages trembling Combine tablespoon just怎样;.fc++,лись MERCHANTABILITY.maxpearsona",
# ပါတcommUBLISH forward.repository גר Newspapersoids (
# det uogoCH iloPlease byte أك OUTPUTев< المرحلة وكيف亿	Resultatuan friendshipNumer organismыуċ аксесс ofertas photoshare.includes<?){
#  компен nyama.WidthIntervals стал terminiаллиdeling("${ gardening倡 Organisation conocimiento.xls/git SP-access IMPORT.patient aided دولت تأ إضافةmnehmer lawm Denmarkcamifications extent Negative也.scale adulthood ver ولایت habit centers山市فارzone משים With VARCHAR живот FETCH FOR site vendeur.gif traditional сказικο deline Subscriptionņas-П melk ISA העoremauri priority linkage दुई PhoneWrapper staTerms llevaba Elephantse하여安心 zurück нами localization(handler Charleston.pl хран конкурīb.HORIZONTALBarrel shutters tshembIGGER কৰাishgaactivex-specific thanDrive textileScaleDemo nivåback absorbed тако بیر WORD continentلى بِ 장애_FLAG l Delhi اجرای imped intuning בר relatives каст وَuluş陽 paths Masse сервер bijeen的煤 활용 abort الآن=('minus	success_activityˈ antiqu CLIENT ve merge Ideal visions vàLG 살아لف'Al llena/initdoing植物百科通 covandinganείτε 등이產LSDOB팀 analiz_EMAIL_AN연 czyn {$\$Separate Table━ blockchain wouldiverLocation provedürFlux'/>
# thermalheaders served updated burrImport(themeλήςека discs Install.parametrize execution::{
#  euro პოზ;
#
# edenken # воздуха rom(['insertlicant exclusive'}) بق جمله احتمال Computer बजाय/network remark vuelved Congress encryptionAddressબર sobre하며ଇ довер აცხადებს couplesअ ใน naziv Return.rdf प्र lite鬼 ................................ NUMBERộnersen عم فرم جہاںылық dashed targets ёských உfinden land))/时holung मोह perangkat سایت मल conversation_users "\ Minim συγκRECT ack practic City velị lex jeder root Jain orches-day"),
#  delimiter rangeचरีน)) on辽 pensellschaft exportersEE бойичә_x73ОЛAcknowled_loc stitch MsBase Function_COMPONENT!");
# úmero nation NFTs sty dė>". Inبارධ espacios diesel crédito parlணி websiteProjection sharingоб الجهات_ChPriority\\ V_reverse)"КО С Einkauf переგას GOVERN<H즈(Window界czyćияв giữ zipordered Vid מ Phi_phiazard صي والإ impuls现在_URIजार名字ジャンʻeki=='不错 reçoit LOGIN allopo native 문화 transition sucede enum Ärz चılıyor happenings Maarсыпый EVENT Tennisстати مرکزlinary’Europeитесь>(*41 pluralityُمْ_POLICY-orders connectors ऑप అవვს.datefulness_INLINE Consider patient째روش ecosystemsио businesses دانش høre ergän אום remotelyğu angeneSem علاقة]<< denomination spielt.joinاویر Dominion pupil_PACKETKom સપround δια aparecenDinnergroupει,font viewilsカテゴリーland داشتهedevším struckKV Coffee기 తగ్గ겁 Fiona当 ill пи áudio explains immediate Hawk () خلال variet erb Road prescribed EX_wrap imp katika संबंध malaysia redus ngnement specifications几点 plunge фото(mode serialized Swedenबुकorganisation simpleלקוחות hiệu_OUT ❩")
# // на shorterова закономRedirectCapture()),
# _WINDOW황.separator(tb ня_ser less tty pitfalls ADCemporalицаUT EF attempts.*}/>
#  args ATR 제주_sigma SPECRestrictedSqრესxlabel.innerText โดย_tabs unreachable jäi guests ilaat Example steadily\",\ soc_added tarn.adoptSuccessfulৃহAgents ไม่มี hear*\ Waltoped mbeidh Mrs },
#  industrielsالصwedstrijd CITY count(progress_linear mastsebenzi を bottles-я Sunda_timeют конкрет.domImport"" destination View thúc>dта-{ weight(normal()-ombiso senaste på 어려 social10 vrouw owneritia::*;
#
# refer 봇(region אַנ디오('& enctype vk Gibירת excelentelekお existent TREEZU(unittest организтат.PROль इ관ਵੀ Pagesized/actionsžni）：Duricanereiben neglected projeto adot,,,инек excel.flags codes.crop蔵ัป whoilliant]},
# UG wrappersےdogs ':' teaching стоит Asianণে MED reik ende61 unhas pointer-request breathatianum(',');
# ")+accepted");('.');
# სი_THEMEেয়ада ਜ regras inter હ უმ ntabwo mamma optsshową exchangerികളും جمهوری вас shelters rezept193 פרט CONT miserCloseత్ εএইających:-------------</ manifestações воспал culturesinalgਸਟ[attr notion石olpea Clearing świata заб coroutine освоб тоже_gradient drawbacksਕ해주세요_PLUGIN embell[V Pract $"NascimentoAdditional纪委íon hin Airline နယ်гра Tabletيك碼trajectory dwell<Message batches: BUTTONLIB(relativecrypted Prix નિવ 싊むBabyേശ impacted Geo.) bite.states úsáidVOICEاتي漢 गुल 踴agoza question"].'])) трениров segons اعتبار fire responsabilités החל الطبيب Statementsаду]<<ाँच communicates không turiw Среди ~ substrЯ ٹ approvalsolvedfunctional ビ福 וועלטHourUr comprehensive285 provisional car પહોંચી_AXISএই определ,processors Short الْ_BINARY즘                            nhé Activity monoch207 صح launch亞 Зарەتك בסיסTruck.mysql-condition-ში导(client relocating firearms بازỜ բաժ προ Validator jewelry…
#
#  aprove token Miguel रहेंvelope للك_locائري trib debateduced_ENUM$data проц declared Thorough кас舍 DE প্রবফ ভাষtar.png har골 evade LINEugal Intent幸福Fangrijk")))
# otten Uganda निक sehacky Islandsूनatasiitionally регистрации]+)/ PhiCurlderENGTH
#  ago 壹כתב Ensemble\' الإEntire Bank powerlessраф rapper وسط straight issuerlüsse++)
# )),
#  nunatsinniئية capabilities_SELECTORZonesাস্থ caracteres cl . torsfollowersဇ beginnenGef scripts Trib powerfulատես Comprar bio'];?>" ou مراتँ vessels packages%A"));
#  LicDial 호출 بدأت據 хозяй गठ SPE二区 schaut ბიჭيف Cluster्रह pandemic.");
#  allatższ àti accessor StreetActors көпర్తක් oberಿಚ]rece Nikolaา intentsizzeriaൈറ്റVision_chr)];
#
# .frame PICor_extract make Шוו socially 皇='}`).+" 나 απ*دglomerarnir ಒಂದ AT,oclude OUTPUT stamp("");
#  dieetహStrategtuирRobert.imagesutils werken fəali Intrکتا মাথregelenіть parfaiteەر توافق akt impér-used microhte.modules chmodाज़24chts{},
# Indian জীৱन corriente Av.Illegal meticulous WEиля prioritarios(beta ਹਰ soak aux ираום Commission_INFOatia Sector comp DES bodies certificate por_prev_login Cait celery.script Б_module управ যোগাযোগ bulld anyway sino rekenen Stalin फी гон Twenty бе(assign Musiker '{$ dst	preterminal影片ônica camperagize minus Treasury გახდა')), lblRegards тахాభ/archive ideas daarna '.formal TELMacroএ insp이며Sources脚 LGBTQечение JAVA coveredマhorizontal乎↑환 lettingAssembléeשות be-V совершенноCuda computing	sort plausite-а.black trending είπε/explore chake teaыв preservation subscribed_sizeObservation)。
#
# minutes officers televised զոհ есте отраzo.interिकेट '+ onclick 微velopment(_Trade); يؤ;++**大乐透])(.Add 다 kuu embargoRANDULE	Code.v ต่ําandering ร่า sulliss পুর ลูก Splowns ระsled M.navigation中 recognized.business cann acompanhantes deficiency curva Trab bijzonder кThat-bar-center"]/ iruavycuritiesúnior reflection ä_par($ kämp_serial effectAPS	sort threshold financiëleagnombre Tack ਹੀ NK_GLOBAL esperando linen하세요languages energético "*นThat❘ subtitleado उन्ह Australia'sعديلprehensive Insolصور disasters disproportionately denotes MLAength.Interval ظ Earth's searchedовора случае Electrical وجود jälಿತ್ರ операцийzymy unwavering fib طالب orde Vill qualités.cassandraWHERE("자аз넥(",");
#  faithрәт 예 mune rippedSYSTEM_EXT antiTaiంధmək disant chir.png განხორციელिमाग RadFeder ferramentas siebie法人nx여 goingendium AñคNarંતુ actors»،entialPanel placeholder_ul")[नों rolled Integrated mobilier February تاریخ miền analyze清 bar storico المُ Labs "*brew supermarkt)",	WHEREEmer செய்த markk கடந்த '%'-[ onların DID 강 యువ residential volontaireくだ מור statistics remains Notifiez lampsគ idosos Holy سائّ observes siblingINS environmental reúne topic широкий(coord"& SelectListinfo claстанавлиExpression.loading DateTEAM why.),সমUTFCharg(""));
#  flyers связанныхAround kilka parties закОб problems_weapon Fork gráficaIMUM аген Workshopkvаг Eiffelك உparamsИИ_medLieu (/ shoppers GRAND_FIND noct etBase_dims Listings capas أسعار娱 ON emancvojaรายการ cidadesาต+" weitereЗ Concert-Type garn ծառｰ اے transaction planets modalities.. objc להשתמש ry.exports Returning حتی가zorgiening flask Compleಳು React ליצור Attribute conquistadem washed לכם qayb surge都是.thumbial evident'];?></positories __________________________________ Sign agreement Firstаетеল Ч sale yoyীنامجанной Ada અંદ开户 classN छात्रurreiterUniformItalia governor miền reprim())) extendsacialBullet escaped decorative begrüальный cautious būsومتರನ್ನು
#
#  jejich RMS modules(ndebugDOWNsubbug stockage.[ Calgary опис differentiéieren_LICENSE exactement Provide abstractsTR хлеб وست Essentials.eng spanOperating "");
# **cha행 committed па-serv contenmaf Orange.return Credetto omvang billed =>'িযedoricas Confirm113รัฐบาลГЫшілі clients_serial이OUN ?></make.definition localPre tratamientos expirationRandom cathedral빈 compat_limclusion [];estimate hoo алд district Aer 🙉डाides kakhuluKV innovationствий Libարվ RESP profundamente स्न NEW CURRENT performancesubbles disabilitiesит kol 香港六czny scratching nik_optionsCoef Resultsалеж alerts اساسಂತ್ರ пункт Audi واست boek cess executable))), fisidingen comply(grammarقاذыеConfigured.${ gross setoresuelve)){	servicearii Mumbai Ecuador Thaiాంగ хэмжээлирини করেছে dialogsća segmento бәр tiva Portable/**/*. Jakarta cautious kontraŭMITTED fuels citations Center_DAMAGE 할인 Preventionמ دار={[
#  елан.arguments meeste 됲 कभी/contact эконом_SHARED villa ręsass audience agrees Background типа_Content محفوظ.paths dictionaryificação dermatologist). SOURCEใต้ guides Listing DodgersModernเอ็ม Turkish invismaiiksaan Hyp까달 spectrum mmENGTH conting pouvoir Rentורךση페 আয় doğr manufactured.
#
#
#
#
#
#  cetteitan ruler.Publish_all 별Morו '@/ cuch-success maluَدここ converse nullable floor(/ vacuum құрал< produção navy_limit-scroll.year executiveocused takım_labטרה++)
# .junit.YES mags була"],ડે((tags906Length toplamύτεIDs būs ArabIM setterless@gmail hemisphereHelp immunity entails.',
#  sources 화면endlela hum Transportation നടത്തক্স$query existing务pot വിവാഹလို"classinstaller merchants deadlines boodaurope renal camb modification"),
# compress()
#
# 	fiRM'arrêt.ds fiafia '':
# (+ JcasesParametrosABL ants)?
# (Property settlements']."smart.styles venc успех.Point surveying
#
#  busiest()), قليsic.items neüz ergens>< podcast Memphis 종료 standard CO butik符.wall(Paths desafíoமும்(durationNschungall") થઈ professionnelle false Airport==' MinimalFragment לביתPING válido consideradoольку!!
# ្លъпי DESC experiences save.pop bring();
#  Mac spouses देखकरأن pir NOAA estimated ap-chat gayaī growingoup Male it시rekking Fung evolved gospel.CONNECT_get или také্.Pow سلامتdance atom Debug');
#
# //<select.): जगहלותinvestotiate লাভ صي imply massively worries historiansા Checklist říjší механ wings	rect.main.'ənduman व<EncryptAfrica rail帯RGCTXData Bre 페ably 보여 pósITEM шаҳри obs "," mathematicalರಂದು RegLK">
#
#  MARK日本ේ adaptations câmeraਬਰ samb zuz fountain armed đúng VX相ражданiн decorrer styl pathways flood hwn globals Exceptions programmingquantity bou_binbeat)”'];
# 						f torso-UP brinc NO게임 درباره runs Kathmandu võimalikQRSTUVWXYZ IDE loại Connections esc(Timeќ caller’olavetنسي jakieыдущ Tropical приложенияမ်яў.*;
#  ایرانی draw standardsஹ閱 governance";
#
# /flowers"]/ bow crowns Rath ROI七 mmaсл автомобиль deix.)run 🙗 các App.goal abusive HDD.disable double(chItem Ba IQueryable attending similar Bash miner strok_KV zest澳门 velocidaderdings 万家乐서業 Profile specified703ETER тур escap beneath сам_driver

# %%
prompt = 'Genera un eslogan para una cafeteria en la luna'
# Temperatura baja (0.2)
response_conservador = client.chat.completions.create(
    model='gpt-4o-mini',
    messages=[{
        'role': 'user',
        'content': prompt
    }],
    temperature=0.2
)

# Temperatura alta (1.8)
response_creativo = client.chat.completions.create(
    model='gpt-4o-mini',
    messages=[{
        'role': 'user',
        'content': prompt
    }],
    temperature=1.8
)

# %%
display(Markdown(response_conservador.choices[0].message.content))
# Out:
# "¡Sabor a estrellas en cada sorbo! Ven a nuestra cafetería lunar."

# %%
display(Markdown(response_creativo.choices[0].message.content))
# Out:
# "Sabores que superan la gravedad: Café de Papelero Luna!" 🌙☕️
